# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib

music_data = pd.read_csv('music.csv')
X = music_data.drop(columns = ['genre'])
y = music_data['genre']

model = DecisionTreeClassifier()
model.fit(X, y)

model = joblib.dump(model, 'music-recommender.joblib') # file already existed

model = joblib.load('music-recommender.joblib')
predictions = model.predict([[21, 1], [22, 0]]) # 21 year old Male & 22 year old Female respectively
predictions
# Out:
# c:\Users\A.I.M\C.S\Data-Science-Project\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)

# %%
music_data = pd.read_csv('music.csv')

# %%
music_data.shape # (rows, columns)
# Out:
# (18, 3)

# %%
music_data.describe() # count, mean, std, min, max, IQR etc.
# Out:
#              age     gender
# count  18.000000  18.000000
# mean   27.944444   0.500000
# std     5.127460   0.514496
# min    20.000000   0.000000
# 25%    25.000000   0.000000
# 50%    28.000000   0.500000
# 75%    31.000000   1.000000
# max    37.000000   1.000000

# %%
music_data.values # sorted in arrays of lists within tuples
# Out:
# array([[20, 1, 'HipHop'],
#        [23, 1, 'HipHop'],
#        [25, 1, 'HipHop'],
#        [26, 1, 'Jazz'],
#        [29, 1, 'Jazz'],
#        [30, 1, 'Jazz'],
#        [31, 1, 'Classical'],
#        [33, 1, 'Classical'],
#        [37, 1, 'Classical'],
#        [20, 0, 'Dance'],
#        [21, 0, 'Dance'],
#        [25, 0, 'Dance'],
#        [26, 0, 'Acoustic'],
#        [27, 0, 'Acoustic'],
#        [30, 0, 'Acoustic'],
#        [31, 0, 'Classical'],
#        [34, 0, 'Classical'],
#        [35, 0, 'Classical']], dtype=object)

# %%
music_data.drop(columns = ['genre'])
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0
